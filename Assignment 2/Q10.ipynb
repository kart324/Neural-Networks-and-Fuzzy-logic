# %% [markdown]
# # 2D Deep CNN

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
from PIL import Image
import glob 
import PIL
import keras 
import tensorflow as tf #importing tensorflow as backend
import sklearn
import numpy as np
import pandas as pd
import scipy.io as sio 
import matplotlib.pyplot as plt

from sklearn.model_selection import KFold
from sklearn import preprocessing
from sklearn.metrics import classification_report,confusion_matrix
from sklearn.model_selection import train_test_split

from keras.models import Sequential,Model
from keras.layers import Input, Dense, Activation, Flatten, Conv2D, Dropout,MaxPooling2D,MaxPool2D,BatchNormalization
from keras.optimizers import SGD,Adam
from keras.utils import np_utils
from sklearn.utils import shuffle

# %%
X=[]
y=[]
img_dir = "/content/drive/MyDrive/2018A8PS1229H_NNFL/Data/class1_images/class1_images.zip (Unzipped Files)/class1_images"
data_path = os.path.join(img_dir,'*g') 
files = glob.glob(data_path) 
for f1 in files:
  X.append(np.asarray((Image.open(f1)).resize((128,128))))
  y.append(0)
img_dir = "/content/drive/MyDrive/2018A8PS1229H_NNFL/Data/class2_images/class2_images.zip (Unzipped Files)/class2_images"  
data_path = os.path.join(img_dir,'*g') 
files = glob.glob(data_path) 
for f1 in files:
  X.append(np.asarray((Image.open(f1)).resize((128,128))))
  y.append(1)
img_dir = "/content/drive/MyDrive/2018A8PS1229H_NNFL/Data/class3_images/class3_images.zip (Unzipped Files)/class3_images"  
data_path = os.path.join(img_dir,'*g') 
files = glob.glob(data_path) 
for f1 in files:
  X.append(np.asarray((Image.open(f1)).resize((128,128))))
  y.append(2)

# %%
X=np.asarray(X)
y=np.asarray(y)
X=X/255.0

# %%
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
train_X,test_X,train_y,test_y=train_test_split(X,y,test_size=0.2,train_size=0.8,random_state=0)
train_X,valid_X,train_y,valid_y=train_test_split(train_X,train_y,test_size=1/8,train_size=7/8,random_state=0)

# %%
def create_model():
  model = Sequential()
  model.add(Conv2D(filters = 8, kernel_size = (3,3), input_shape=(128, 128, 3), padding = "same"))
  model.add(MaxPooling2D(pool_size=(2, 2), strides=(1, 1), padding='same'))
  model.add(Activation('relu'))
  
  model.add(Conv2D(filters = 16, kernel_size = (3,3), padding = "same"))
  model.add(MaxPooling2D(pool_size=(2, 2), strides=(1, 1), padding='same'))
  
  model.add(Conv2D(filters = 32, kernel_size = (3,3), padding = "same"))
  model.add(MaxPooling2D(pool_size=(2, 2), strides=(3, 3), padding='same'))
  #model.add(Activation('relu'))
  
  model.add(Conv2D(filters = 32, kernel_size = (3,3), padding = "same"))
  model.add(Flatten())
  
  model.add(Dense(128))
  model.add(Activation('relu'))
  
  model.add(Dense(64))
  model.add(Dropout(0.3))
  model.add(Activation('relu'))
  
  model.add(Dense(32))
  model.add(Activation('relu'))
  
  model.add(Dense(16))
  model.add(Dropout(0.3))
  model.add(Activation('relu'))
  
  model.add(Dense(3))
  model.add(Activation('softmax'))
  return model

# %%
modelf=create_model()
modelf.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 128, 128, 8)       224
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 128, 128, 8)       0
# _________________________________________________________________
# activation (Activation)      (None, 128, 128, 8)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 128, 128, 16)      1168
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 128, 128, 16)      0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 128, 128, 32)      4640
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 43, 43, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 43, 43, 32)        9248
# _________________________________________________________________
# flatten (Flatten)            (None, 59168)             0
# _________________________________________________________________
# dense (Dense)                (None, 128)               7573632
# _________________________________________________________________
# activation_1 (Activation)    (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dropout (Dropout)            (None, 64)                0
# _________________________________________________________________
# activation_2 (Activation)    (None, 64)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 32)                2080
# _________________________________________________________________
# activation_3 (Activation)    (None, 32)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 16)                528
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 16)                0
# _________________________________________________________________
# activation_4 (Activation)    (None, 16)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 3)                 51
# _________________________________________________________________
# activation_5 (Activation)    (None, 3)                 0
# =================================================================
# Total params: 7,599,827
# Trainable params: 7,599,827
# Non-trainable params: 0
# _________________________________________________________________

# %%
modelf.compile(loss='sparse_categorical_crossentropy', optimizer='sgd', metrics=['accuracy'])
history=modelf.fit(train_X, train_y, epochs=30, batch_size=15,validation_data=(valid_X,valid_y))
print(history)
# Out:
# Epoch 1/30
# 34/34 [==============================] - 22s 639ms/step - loss: 1.0991 - accuracy: 0.3208 - val_loss: 1.0984 - val_accuracy: 0.3151
# Epoch 2/30
# 34/34 [==============================] - 26s 774ms/step - loss: 1.0991 - accuracy: 0.3465 - val_loss: 1.0968 - val_accuracy: 0.5205
# Epoch 3/30
# 34/34 [==============================] - 22s 636ms/step - loss: 1.0969 - accuracy: 0.3446 - val_loss: 1.0956 - val_accuracy: 0.3014
# Epoch 4/30
# 34/34 [==============================] - 22s 654ms/step - loss: 1.0891 - accuracy: 0.3743 - val_loss: 1.0908 - val_accuracy: 0.3014
# Epoch 5/30
# 34/34 [==============================] - 22s 637ms/step - loss: 1.0888 - accuracy: 0.3644 - val_loss: 1.0832 - val_accuracy: 0.3014
# Epoch 6/30
# 34/34 [==============================] - 22s 636ms/step - loss: 1.0732 - accuracy: 0.3960 - val_loss: 1.0625 - val_accuracy: 0.6986
# Epoch 7/30
# 34/34 [==============================] - 22s 637ms/step - loss: 1.0585 - accuracy: 0.4970 - val_loss: 1.0585 - val_accuracy: 0.3014
# Epoch 8/30
# 34/34 [==============================] - 22s 637ms/step - loss: 1.0323 - accuracy: 0.5168 - val_loss: 1.0076 - val_accuracy: 0.9452
# Epoch 9/30
# 34/34 [==============================] - 22s 650ms/step - loss: 0.9733 - accuracy: 0.5822 - val_loss: 0.9486 - val_accuracy: 0.6712
# Epoch 10/30
# 34/34 [==============================] - 22s 647ms/step - loss: 0.8814 - accuracy: 0.6891 - val_loss: 0.7700 - val_accuracy: 0.9452
# Epoch 11/30
# 34/34 [==============================] - 22s 636ms/step - loss: 0.7911 - accuracy: 0.7248 - val_loss: 0.6946 - val_accuracy: 0.9726
# Epoch 12/30
# 34/34 [==============================] - 22s 637ms/step - loss: 0.6241 - accuracy: 0.8040 - val_loss: 0.4317 - val_accuracy: 0.8904
# Epoch 13/30
# 34/34 [==============================] - 22s 635ms/step - loss: 0.3744 - accuracy: 0.8931 - val_loss: 0.1325 - val_accuracy: 0.9863
# Epoch 14/30
# 34/34 [==============================] - 22s 634ms/step - loss: 0.2430 - accuracy: 0.9248 - val_loss: 0.0432 - val_accuracy: 1.0000
# Epoch 15/30
# 34/34 [==============================] - 22s 636ms/step - loss: 0.1481 - accuracy: 0.9564 - val_loss: 0.0200 - val_accuracy: 1.0000
# Epoch 16/30
# 34/34 [==============================] - 22s 637ms/step - loss: 0.1252 - accuracy: 0.9624 - val_loss: 0.0127 - val_accuracy: 1.0000
# Epoch 17/30
# 34/34 [==============================] - 22s 637ms/step - loss: 0.1160 - accuracy: 0.9584 - val_loss: 0.0094 - val_accuracy: 1.0000
# Epoch 18/30
# 34/34 [==============================] - 22s 650ms/step - loss: 0.0771 - accuracy: 0.9762 - val_loss: 0.0033 - val_accuracy: 1.0000
# Epoch 19/30
# 34/34 [==============================] - 22s 636ms/step - loss: 0.0737 - accuracy: 0.9743 - val_loss: 0.0032 - val_accuracy: 1.0000
# Epoch 20/30
# 34/34 [==============================] - 22s 640ms/step - loss: 0.0391 - accuracy: 0.9921 - val_loss: 5.9714e-04 - val_accuracy: 1.0000
# Epoch 21/30
# 34/34 [==============================] - 22s 634ms/step - loss: 0.0490 - accuracy: 0.9941 - val_loss: 5.1570e-04 - val_accuracy: 1.0000
# Epoch 22/30
# 34/34 [==============================] - 22s 636ms/step - loss: 0.0944 - accuracy: 0.9683 - val_loss: 0.0328 - val_accuracy: 1.0000
# Epoch 23/30
# 34/34 [==============================] - 22s 641ms/step - loss: 0.0460 - accuracy: 0.9941 - val_loss: 0.0020 - val_accuracy: 1.0000
# Epoch 24/30
# 34/34 [==============================] - 22s 651ms/step - loss: 0.0460 - accuracy: 0.9782 - val_loss: 4.0408e-04 - val_accuracy: 1.0000
# Epoch 25/30
# 34/34 [==============================] - 22s 635ms/step - loss: 0.0263 - accuracy: 0.9941 - val_loss: 3.4306e-04 - val_accuracy: 1.0000
# Epoch 26/30
# 34/34 [==============================] - 22s 640ms/step - loss: 0.0365 - accuracy: 0.9861 - val_loss: 1.4189e-04 - val_accuracy: 1.0000
# Epoch 27/30
# 34/34 [==============================] - 22s 635ms/step - loss: 0.0215 - accuracy: 0.9901 - val_loss: 1.1019e-04 - val_accuracy: 1.0000
# Epoch 28/30
# 34/34 [==============================] - 22s 636ms/step - loss: 0.0263 - accuracy: 0.9901 - val_loss: 1.2115e-04 - val_accuracy: 1.0000
# Epoch 29/30
# 34/34 [==============================] - 26s 770ms/step - loss: 0.0304 - accuracy: 0.9861 - val_loss: 1.3077e-04 - val_accuracy: 1.0000
# Epoch 30/30
# 34/34 [==============================] - 22s 634ms/step - loss: 0.0173 - accuracy: 0.9941 - val_loss: 1.3863e-04 - val_accuracy: 1.0000
# <tensorflow.python.keras.callbacks.History object at 0x7f25dced5f60>

# %%
#plotting the loss graph
plt.plot(history.history['loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epochs')
# Out:
# Text(0.5, 0, 'Epochs')

# %%
#Confusion Matrix
test_y=test_y+1
y_pred=np.argmax(modelf.predict(test_X), axis=-1)+1
cm=pd.crosstab(test_y,y_pred)
print("Confusion matrix:\n")
cm
# Out:
# Confusion matrix:
# col_0   1   2   3
# row_0
# 1      42   0   0
# 2       0  58   0
# 3       0   0  45

# %%
print("Individual class accuracy:")
cm=confusion_matrix(test_y,y_pred)
for i in range(3):
  print(f'Class {i+1} accuracy: ', end="")
  print((cm.diagonal()/cm.sum(axis=1))[i] *100) #Individual Class Accuracy
# Out:
# Individual class accuracy:
# Class 1 accuracy: 100.0
# Class 2 accuracy: 100.0
# Class 3 accuracy: 100.0

# %%
print(f"Overall Accuracy: {np.sum(y_pred==test_y)/len(test_y) *100}%")
# Out:
# Overall Accuracy: 100.0%

# %%
def call_model(tr_x,tr_y):
  modelk=create_model()
  modelk.compile(loss='sparse_categorical_crossentropy', optimizer='sgd', metrics=['accuracy'])
  modelk.fit(tr_x,tr_y, epochs=20, batch_size=15,verbose=0,shuffle=False)
  return modelk

# %%
j=1
Xs, ys = shuffle(X, y,random_state=0)
kf=KFold(n_splits=10)
accs = 0
for train,test in kf.split(Xs):
    print()
    print(f"Fold {j}:")
    j=j+1
    tr_x,tr_y,ts_x,ts_y=Xs[train],ys[train],Xs[test],ys[test]
    tf.compat.v1.disable_eager_execution()
    y_pred=np.argmax(call_model(tr_x,tr_y).predict(ts_x), axis=-1)
    cm=confusion_matrix(ts_y,y_pred)
    print("Confusion matrix:")
    print(cm)
    print("Individual class accuracy:")
    for i in range(3):
        print(f"Class {i+1}: ", end = "")
        print((cm.diagonal()/cm.sum(axis=1))[i] *100) #Individual Class Accuracy
    acc = np.sum(y_pred==ts_y)/len(ts_y)
    accs += acc
    print(f"Overall Accuracy: {acc*100}%")
    print("====================================")

print(f"Average Accuracy: {accs*100/10}%")
# Out:
# Fold 1:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training_v1.py:2070: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# Confusion matrix:
# [[20  0  0]
#  [ 0 29  0]
#  [ 0  0 24]]
# Individual class accuracy:
# Class 1: 100.0
# Class 2: 100.0
# Class 3: 100.0
# Overall Accuracy: 100.0%
# ====================================
#
# Fold 2:
# Confusion matrix:
# [[22  0  0]
#  [ 0 30  0]
#  [ 0  0 21]]
# Individual class accuracy:
# Class 1: 100.0
# Class 2: 100.0
# Class 3: 100.0
# Overall Accuracy: 100.0%
# ====================================
#
# Fold 3:
# Confusion matrix:
# [[22  0  0]
#  [ 0 23  0]
#  [ 1  0 27]]
# Individual class accuracy:
# Class 1: 100.0
# Class 2: 100.0
# Class 3: 96.42857142857143
# Overall Accuracy: 98.63013698630137%
# ====================================
#
# Fold 4:
# Confusion matrix:
# [[29  0  0]
#  [ 0 26  0]
#  [ 0  0 17]]
# Individual class accuracy:
# Class 1: 100.0
# Class 2: 100.0
# Class 3: 100.0
# Overall Accuracy: 100.0%
# ====================================
#
# Fold 5:
# Confusion matrix:
# [[24  0  0]
#  [ 1 27  0]
#  [ 0  0 20]]
# Individual class accuracy:
# Class 1: 100.0
# Class 2: 96.42857142857143
# Class 3: 100.0
# Overall Accuracy: 98.61111111111111%
# ====================================
#
# Fold 6:
# Confusion matrix:
# [[21  0  0]
#  [ 0 28  0]
#  [ 0  0 23]]
# Individual class accuracy:
# Class 1: 100.0
# Class 2: 100.0
# Class 3: 100.0
# Overall Accuracy: 100.0%
# ====================================
#
# Fold 7:
# Confusion matrix:
# [[23  0  0]
#  [ 0 17  1]
#  [ 0  0 31]]
# Individual class accuracy:
# Class 1: 100.0
# Class 2: 94.44444444444444
# Class 3: 100.0
# Overall Accuracy: 98.61111111111111%
# ====================================
#
# Fold 8:
# Confusion matrix:
# [[28  0  0]
#  [ 0 21  0]
#  [ 0  0 23]]
# Individual class accuracy:
# Class 1: 100.0
# Class 2: 100.0
# Class 3: 100.0
# Overall Accuracy: 100.0%
# ====================================
#
# Fold 9:
# Confusion matrix:
# [[28  0  0]
#  [ 0 25  0]
#  [ 0  0 19]]
# Individual class accuracy:
# Class 1: 100.0
# Class 2: 100.0
# Class 3: 100.0
# Overall Accuracy: 100.0%
# ====================================
#
# Fold 10:
# Confusion matrix:
# [[23  0  0]
#  [ 0 24  0]
#  [ 0  0 25]]
# Individual class accuracy:
# Class 1: 100.0
# Class 2: 100.0
# Class 3: 100.0
# Overall Accuracy: 100.0%
# ====================================
# Average Accuracy: 99.58523592085236%
